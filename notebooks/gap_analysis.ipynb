# %% [markdown]
# # Analysis of Median and Performancee Spread evolution from 2001-05 to 2021-25

# %% [markdown]
# #### Imports and Data Loading

# %%
from lib import util
from lib import plotting_style as plt
import pandas as pd
import numpy as np
import seaborn as sns
import lib.help_functions as hp
from lib.plotting_style import rgb
from scipy import stats


# Manual path, automatic did not work
# data = util.load_data(path_file='C:\\Users\\Mattis\\OneDrive\\Kogni\\DataLiteracyProject\\Data-Literacy\\data_csv\\final_data_iaaf_scores_neu_v2.csv')
data = util.load_data() 

data.head()
# Out:
#    jahr geschlecht altersklasse disziplin  leistung  wind                name  \
# 0  2017          W       Frauen     100 m     10.95   1.3  Gina Lueckenkemper
# 1  2017          W       Frauen     100 m     11.06   1.8       Rebekka Haase
# 2  2017          W       Frauen     100 m     11.14  -0.2          Lisa Mayer
# 3  2017          W       Frauen     100 m     11.24   0.3       Tatjana Pinto
# 4  2017          W       Frauen     100 m     11.25   1.9          Sina Mayer
#
#    geburtsjahr               verein   datum          ort  iaaf_score   group
# 0         1996  LG Olympia Dortmund  05.08.   London/GBR      1211.0  Sprint
# 1         1993     LV 90 Erzgebirge  25.05.   Zeulenroda      1187.0  Sprint
# 2         1996   Sprintteam Wetzlar  27.08.       Berlin      1169.0  Sprint
# 3         1992         LC Paderborn  15.07.   Ninove/BEL      1148.0  Sprint
# 4         1995     LAZ Zweibruecken  11.06.   Regensburg      1146.0  Sprint

# %% [markdown]
# #### Data Preparation

# %%
# Defining Age Groups
data['altersklasse'] = data['altersklasse'].replace({'Maenner': 'Adult', 'Frauen': 'Adult', '18': 'U18', '20': 'U20'})

# Get Data for Analysis, top 35, exclude U23
summary = data.groupby(['jahr', 'altersklasse', 'geschlecht', 'disziplin']).size().reset_index(name='anzahl')
under = summary[(summary['altersklasse'] == 'U23') | (summary['anzahl'] < 35)]
under = under.sort_values(by=['jahr', 'altersklasse', 'geschlecht', 'disziplin'])
data_all = data.groupby(['jahr', 'altersklasse', 'geschlecht', 'disziplin']).filter(lambda x: x.name[1] != 'U23' and len(x) >= 35)

# Exclude changes in weights/heights in 2001
u20_changes = ['Kugelstoss', 'Hammerwurf', 'Diskuswurf', '110 m Huerden']
mask_u20_2001 = (data_all['altersklasse'] == 'U20') & \
                (data_all['disziplin'].isin(u20_changes)) & \
                (data_all['jahr'] == 2001)

data_all = data_all[~mask_u20_2001]

# Make sure getting all Data
data_all = data_all.sort_values(by='iaaf_score', ascending=False)
data_all = data_all.groupby(['jahr', 'altersklasse', 'geschlecht', 'disziplin']).head(35)

data['altersklasse'].unique()
# Out:
# array(['Adult', 'U18', 'U20', 'U23'], dtype=object)

# %% [markdown]
# All Groups with some missing data. If 5 years in a period are missing, they are not integrated in the future analysis. For the others the data is just calculated over 4/3 years. There is no group, wehre only 2 years or 1 year are available.

# %%
years_start = set(range(2001, 2006))
years_end = set(range(2021, 2026))

check_years = data_all.groupby(['altersklasse', 'geschlecht', 'disziplin'])['jahr'].unique().reset_index()

def find_missing_periods(row):
    present_years = set(row['jahr'])
    missing_start = years_start - present_years
    missing_end = years_end - present_years
    
    if missing_start or missing_end:
        return f"Missing Start: {missing_start if missing_start else 'None'}, Missing End: {missing_end if missing_end else 'None'}"
    return None

check_years['missing_info'] = check_years.apply(find_missing_periods, axis=1)

incomplete_groups = check_years.dropna(subset=['missing_info'])


pd.set_option('display.max_rows', None) # Alles anzeigen
print(incomplete_groups[['altersklasse', 'geschlecht', 'disziplin', 'missing_info']])
pd.reset_option('display.max_rows')
# Out:
#     altersklasse geschlecht         disziplin  \
# 16         Adult          M          Marathon
# 20         Adult          W          10 000 m
# 26         Adult          W  3000 m Hindernis
# 41           U18          M     110 m Huerden
# 42           U18          M            1500 m
# 43           U18          M             200 m
# 44           U18          M  2000 m Hindernis
# 48           U18          M             800 m
# 58           U18          W     100 m Huerden
# 61           U18          W  2000 m Hindernis
# 75           U20          M     110 m Huerden
# 79           U20          M  3000 m Hindernis
# 82           U20          M            5000 m
# 84           U20          M        Diskuswurf
# 86           U20          M        Hammerwurf
# 88           U20          M        Kugelstoss
# 91           U20          M        Weitsprung
# 101          U20          W        Diskuswurf
# 103          U20          W        Hammerwurf
# 105          U20          W        Kugelstoss
#
#                                           missing_info
# 16      Missing Start: None, Missing End: {2025, 2023}
# 20            Missing Start: {2002}, Missing End: None
# 26   Missing Start: {2001, 2002, 2003, 2004, 2005},...
# 41            Missing Start: {2003}, Missing End: None
# 42            Missing Start: None, Missing End: {2024}
# 43            Missing Start: {2002}, Missing End: None
# 44            Missing Start: None, Missing End: {2025}
# 48            Missing Start: None, Missing End: {2024}
# 58            Missing Start: {2001}, Missing End: None
# 61   Missing Start: {2001, 2002, 2003, 2004, 2005},...
# 75            Missing Start: {2001}, Missing End: None
# 79   Missing Start: {2001, 2002, 2003, 2004, 2005},...
# 82            Missing Start: {2002}, Missing End: None
# 84            Missing Start: {2001}, Missing End: None
# 86            Missing Start: {2001}, Missing End: None
# 88            Missing Start: {2001}, Missing End: None
# 91            Missing Start: {2003}, Missing End: None
# 101           Missing Start: {2001}, Missing End: None
# 103           Missing Start: {2001}, Missing End: None
# 105           Missing Start: {2001}, Missing End: None

# %% [markdown]
# #### Median, Performance Gap und Signifikanztests

# %%
def get_analysis_data(df, group_cols, start_period=(2001, 2005), end_period=(2021, 2025)):
    results = []
    
    grouped = df.groupby(group_cols) if group_cols else [("Global", df)]

    for names, subgroup in grouped:

        current_group = subgroup['group'].iloc[0]
        
        # Performance Gap
        def get_period_pool(data, years):
            period_data = data[data["jahr"].between(*years)]
            
            top_pool = (period_data.groupby("jahr")["iaaf_score"].nlargest(3).reset_index(drop=True))
            
            low_pool = (period_data.groupby("jahr")["iaaf_score"].nsmallest(3).reset_index(drop=True))
            
            return top_pool, low_pool

        s_top, s_low = get_period_pool(subgroup, start_period)
        e_top, e_low = get_period_pool(subgroup, end_period)

        s_pool = subgroup[subgroup["jahr"].between(*start_period)]["iaaf_score"].dropna()
        e_pool = subgroup[subgroup["jahr"].between(*end_period)]["iaaf_score"].dropna()

        if len(s_top) > 1 and len(e_top) > 1 and len(s_low) > 1 and len(e_low) > 1:
            # Mann-Whitney-U-Test for median comparison
            u_stat, p_median = stats.mannwhitneyu(e_pool, s_pool, alternative='two-sided')

            # Medians
            med_e, med_s = np.median(e_pool), np.median(s_pool)

            # Effect size r
            n_total = len(e_pool) + len(s_pool)
            z_score = stats.norm.ppf(p_median / 2) # approximation
            r_effect = abs(z_score) / np.sqrt(n_total)

            m_diff_perc = (med_e - med_s) / med_s * 100

            # Performance Gap
            gap_s = s_top.mean() - s_low.mean()
            gap_e = e_top.mean() - e_low.mean()

            top_3_avg_s = s_top.mean()
            low_3_avg_s = s_low.mean()
            top_3_avg_e = e_top.mean()
            low_3_avg_e = e_low.mean()

            obs_diff = gap_e - gap_s

            # Bootstrap
            boot_diffs = []
            for _ in range(10000):
                # Resampling 
                s_top_res = np.random.choice(s_top, size=len(s_top), replace=True).mean()
                s_low_res = np.random.choice(s_low, size=len(s_low), replace=True).mean()
                e_top_res = np.random.choice(e_top, size=len(e_top), replace=True).mean()
                e_low_res = np.random.choice(e_low, size=len(e_low), replace=True).mean()
                
                boot_diffs.append((e_top_res - e_low_res) - (s_top_res - s_low_res))
            
            boot_diffs = np.array(boot_diffs)
            ci_low = np.percentile(boot_diffs, 2.5)
            ci_high = np.percentile(boot_diffs, 97.5)

            std_boot = np.std(boot_diffs)
            effect_size_d = obs_diff / std_boot if std_boot != 0 else 0
            
            # P-value for the gap
            p_gap = np.mean(np.abs(boot_diffs - np.mean(boot_diffs)) >= np.abs(obs_diff))

            # Gap difference percentage
            gap_diff_perc = ((gap_e - gap_s) / gap_s * 100) if gap_s > 0 else 0

            res = {col: val for col, val in zip(group_cols, names)} if group_cols else {"Group": "Global"}
            res.update({
                "Median_Start": round(med_s, 2),
                "Median_End": round(med_e, 2),
                "Median_Diff_Abs": round((med_e - med_s), 2),
                "Median_Diff_%": round(m_diff_perc, 2),
                "P_Val_MWU": round(p_median, 4),
                "MWU_sig": "Yes" if p_median < 0.05 else "No",
                "Effect_r": round(r_effect, 3),
                "Gap_Start": round(gap_s, 2),
                "Gap_Start_top3_avg": round(top_3_avg_s, 2),
                "Gap_Start_low3_avg": round(low_3_avg_s, 2),
                "Gap_End": round(gap_e, 2),
                "Gap_End_top3_avg": round(top_3_avg_e, 2),
                "Gap_End_low3_avg": round(low_3_avg_e, 2),
                "Gap_Diff_Abs": round(obs_diff, 2),
                "Gap_Diff_%": round(gap_diff_perc, 2),
                "Gap_CI_Lower": round(ci_low, 2),
                "Gap_CI_Upper": round(ci_high, 2),
                "Gap_Sig_Bootstrap": "Yes" if ci_low > 0 or ci_high < 0 else "No",
                "Gap_Effect_Size": round(effect_size_d, 3),
                "group": current_group
            })
            results.append(res)

    return pd.DataFrame(results)

analysis_results = get_analysis_data(data_all, group_cols=['altersklasse', 'geschlecht', 'disziplin'])
print(analysis_results['altersklasse'].unique())
analysis_results.head()
# Out:
# ['Adult' 'U18' 'U20']
#   altersklasse geschlecht      disziplin  Median_Start  Median_End  \
# 0        Adult          M       10 000 m         896.0       961.0
# 1        Adult          M          10 km         942.0       992.0
# 2        Adult          M          100 m        1008.0      1076.0
# 3        Adult          M  110 m Huerden        1012.0       979.0
# 4        Adult          M         1500 m        1029.0      1062.0
#
#    Median_Diff_Abs  Median_Diff_%  P_Val_MWU MWU_sig  Effect_r  ...  Gap_End  \
# 0             65.0           7.25        0.0     Yes     0.347  ...   277.53
# 1             50.0           5.31        0.0     Yes     0.447  ...   164.27
# 2             68.0           6.75        0.0     Yes     0.602  ...   140.87
# 3            -33.0          -3.26        0.0     Yes     0.306  ...   225.73
# 4             33.0           3.21        0.0     Yes     0.368  ...   166.87
#
#    Gap_End_top3_avg  Gap_End_low3_avg  Gap_Diff_Abs  Gap_Diff_%  Gap_CI_Lower  \
# 0           1140.60            863.07         86.40       45.20         53.66
# 1           1108.53            944.27         24.13       17.22          5.73
# 2           1175.73           1034.87        -11.67       -7.65        -26.73
# 3           1128.00            902.27         26.60       13.36          8.20
# 4           1180.00           1013.13         27.87       20.05          8.60
#
#    Gap_CI_Upper  Gap_Sig_Bootstrap  Gap_Effect_Size   group
# 0        118.40                Yes            5.255     Run
# 1         43.07                Yes            2.521     Run
# 2          3.27                 No           -1.517  Sprint
# 3         45.07                Yes            2.850  Sprint
# 4         47.47                Yes            2.827     Run
#
# [5 rows x 23 columns]

# %%
# Changes on 2012/13 - we include them in the Gap analysis, but not median analysis
u18_regelaenderung = [
    ('U18', 'W', 'Kugelstoss'),
    ('U18', 'W', 'Hammerwurf'),
    ('U18', 'W', 'Speerwurf'),
    ('U18', 'M', 'Kugelstoss'),
    ('U18', 'M', 'Hammerwurf')
]

analysis_results['Marker'] = 'normal'
mask = analysis_results[['altersklasse', 'geschlecht', 'disziplin']].apply(tuple, axis=1).isin(u18_regelaenderung)
analysis_results.loc[mask, 'Marker'] = 'Regeländerung'

analysis_results['Label'] = analysis_results['disziplin']
analysis_results.loc[mask, 'Label'] = analysis_results['disziplin'] + '*'

cols_to_null = ['Median_Start', 'Median_End', 'Median_Diff_Abs', 'Median_Diff_%', 'P_Val_MWU']
analysis_results.loc[mask, cols_to_null] = np.nan

print(analysis_results[analysis_results['Marker'] == 'Regeländerung'])
# Out:
#    altersklasse geschlecht   disziplin  Median_Start  Median_End  \
# 50          U18          M  Hammerwurf           NaN         NaN
# 52          U18          M  Kugelstoss           NaN         NaN
# 66          U18          W  Hammerwurf           NaN         NaN
# 68          U18          W  Kugelstoss           NaN         NaN
# 69          U18          W   Speerwurf           NaN         NaN
#
#     Median_Diff_Abs  Median_Diff_%  P_Val_MWU MWU_sig  Effect_r  ...  \
# 50              NaN            NaN        NaN     Yes     0.371  ...
# 52              NaN            NaN        NaN     Yes     0.439  ...
# 66              NaN            NaN        NaN     Yes     0.617  ...
# 68              NaN            NaN        NaN     Yes     0.657  ...
# 69              NaN            NaN        NaN     Yes     0.248  ...
#
#     Gap_End_low3_avg  Gap_Diff_Abs  Gap_Diff_%  Gap_CI_Lower  Gap_CI_Upper  \
# 50            581.73         73.33       21.50         28.07        118.60
# 52            779.53         61.07       32.32         16.20        105.87
# 66            674.40         41.60       13.86          1.60         82.34
# 68            766.40         31.13       18.50         -6.67         69.80
# 69            732.27        -19.00       -9.63        -55.87         14.27
#
#     Gap_Sig_Bootstrap  Gap_Effect_Size  group         Marker        Label
# 50                Yes            3.129  Throw  Regeländerung  Hammerwurf*
# 52                Yes            2.645  Throw  Regeländerung  Kugelstoss*
# 66                Yes            2.019  Throw  Regeländerung  Hammerwurf*
# 68                 No            1.597  Throw  Regeländerung  Kugelstoss*
# 69                 No           -1.056  Throw  Regeländerung   Speerwurf*
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Plot of Median against Performance Spread

# %%
plot_data = analysis_results.copy()


def get_point_colors(subset, gender_color):
    face_colors = []
    edge_colors = []
    linewidths = []
    
    for _, row in subset.iterrows():
        # check if change
        if (row['altersklasse'], row['geschlecht'], row['disziplin']) in u18_regelaenderung:
            face_colors.append('#d3d3d3')
            edge_colors.append(gender_color) 
            linewidths.append(2.5) 
        else:
            # Normal colors
            face_colors.append(gender_color)
            edge_colors.append('none')
            linewidths.append(0)
            
    return face_colors, edge_colors, linewidths

# colors = {'M': "#c8564a", 'W': "#5e6be1"} 
# edge_colors = {'M': "blue", 'W': "red"} 
# colors = {'M': plt.rgb.tue_blue, 'W': plt.rgb.tue_red}
colors = {'Adult': "#344953", "U20": "#4dbef7", "U18": "#e67e22"}
labels = {'M': 'Men', 'W': 'Women'}

unique_ages = sorted(plot_data['altersklasse'].unique(), key=lambda x: ['Adult', 'U20', 'U18'].index(x))
print(unique_ages)
marker_styles = ['o', 's', 'D', 'v'] 
marker_map = {age: marker_styles[i] for i, age in enumerate(unique_ages)}

x_limit = max(abs(plot_data["Median_Diff_%"].min()), abs(plot_data["Median_Diff_%"].max())) + 2
# y_limit = max(abs(plot_data["Gap_Diff_%"].min()), abs(plot_data["Gap_Diff_%"].max())) + 10
y_limit_pos = abs(plot_data["Gap_Diff_%"].max()) + 10
y_limit_neg = abs(plot_data["Gap_Diff_%"].min()) + 10

plt.set_column(column="full", ncols=2, nrows=1)
fig, axes = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=True)

# Scatter Plot
for i, gender in enumerate(['M', 'W']):
    ax = axes[i]
    if gender not in plot_data['geschlecht'].unique():
        continue

    ax.fill_between([0, x_limit], -y_limit_neg, 0, color=plt.rgb.tue_lightgreen, alpha=0.3) # Gut
    ax.fill_between([-x_limit, 0], 0, y_limit_pos, color=plt.rgb.tue_red, alpha=0.3)   # Schlecht
    # ax.fill_between([0, x_limit], 0, y_limit, color=plt.rgb.tue_gray, alpha=0.2) # Gemischt
    # ax.fill_between([-x_limit, 0], -y_limit, 0, color=plt.rgb.tue_gray, alpha=0.2) # Gemischt
    ax.fill_between([0, x_limit], 0, y_limit_pos, color=plt.rgb.tue_lightorange, alpha=0.3) # Gemischt
    ax.fill_between([-x_limit, 0], -y_limit_neg, 0, color=plt.rgb.tue_lightorange, alpha=0.3) # Gemisc
    # ax.scatter([], [], color=colors[gender], alpha=0.9)
    
    for age in unique_ages:
        # mask = (plot_data['geschlecht'] == gender) & (plot_data['altersklasse'] == age)
        # subset = plot_data[mask]
        subset = plot_data[(plot_data['geschlecht'] == gender) & (plot_data['altersklasse'] == age)]
        
        if subset.empty:
            continue

        f_color = colors[age]
        edge_color = 'black'

        # Regulation Change
        mask_reg_change = subset['Marker'] == 'Regeländerung'
        sub_reg_change = subset[mask_reg_change]
        if not sub_reg_change.empty:
            print(f"Plotting Regeländerung for {age}, {gender}")
            ax.scatter(
                [0] * len(sub_reg_change["Gap_Diff_%"]), sub_reg_change["Gap_Diff_%"], 
                facecolors=f_color, edgecolors='black',
                marker='*', alpha=1, zorder=5, s=25
            )


        # Not significant
        mask_no = subset['Gap_Sig_Bootstrap'] == 'No'
        sub_no = subset[mask_no]
        if not sub_no.empty:
            # f_cols, e_cols, l_widths = get_point_colors(sub_no, colors[gender])
            ax.scatter(
                sub_no["Median_Diff_%"], sub_no["Gap_Diff_%"], 
                facecolors=f_color, edgecolors='none',
                marker='o', alpha=0.7, zorder=3, s=20
            )

        # Significant
        mask_yes = subset['Gap_Sig_Bootstrap'] == 'Yes'
        sub_yes = subset[mask_yes]
        if not sub_yes.empty:
            # f_cols, e_cols, l_widths = get_point_colors(sub_yes, colors[gender])
            ax.scatter(
                sub_yes["Median_Diff_%"], sub_yes["Gap_Diff_%"], 
                facecolors=f_color, edgecolors=edge_color,
                marker='o', alpha=1, zorder=4, s=20
            )

    for age in unique_ages:
        ax.scatter([], [], facecolor=colors[age], marker='o', 
                label=age, edgecolors='black')
        
    ax.scatter(
        [], [],
        facecolors=plt.rgb.tue_gray, edgecolors='none',
        marker='o', alpha=0.7, zorder=3, label='Not Significant'
    )
        
    ax.scatter([], [], facecolors=plt.rgb.tue_gray, edgecolors='black', 
            marker='*', label='Affected by Regulation Change')

    # Reference Lines
    ax.axvline(0, color=plt.rgb.tue_dark, linestyle='-', alpha=0.3, zorder=2)
    ax.axhline(0, color=plt.rgb.tue_dark, linestyle='-', alpha=0.3, zorder=2)

    # Limits
    ax.set_xlim(-x_limit, x_limit)
    

    ax.set_title(labels[gender])
    ax.grid(True, linestyle=':', alpha=0.3, zorder=0)

handles, labels = axes[1].get_legend_handles_labels()
fig.legend(handles, labels, loc='outside upper center', ncols=5)
axes[0].set_ylabel("Performance Gap Change (\\%)")
fig.text(0.5, -0.04, 'Median Performance Change (\\%)', ha='center')
axes[0].set_ylim(-y_limit_neg, y_limit_pos)

# plt.savefig("gap_performance_change", category="Gap Analysis")
plt.show()
# Out:
# ['Adult', 'U20', 'U18']
# Plotting Regeländerung for U18, M
# Plotting Regeländerung for U18, W

# %%
# Alle 109 Gruppen-Kombinationen anzeigen
all_groups = data_all.groupby(['altersklasse', 'geschlecht', 'disziplin']).size().reset_index()

# Vergleiche das mit deiner Erwartung. 
# Oft sind es "Exoten" oder Schreibfehler in den Disziplinen (z.B. "110m Hürden" vs "110mH")
print(all_groups)

# Zeige nur die Gruppen, die NICHT in deinem Ergebnis gelandet sind
missing_in_results = all_groups[~all_groups.set_index(['altersklasse', 'geschlecht', 'disziplin']).index.isin(analysis_results.set_index(['altersklasse', 'geschlecht', 'disziplin']).index)]
print("Diese Gruppen wurden gar nicht erst berechnet:")
print(missing_in_results)
# Out:
#     altersklasse geschlecht       disziplin    0
# 0          Adult          M        10 000 m  875
# 1          Adult          M           10 km  875
# 2          Adult          M           100 m  875
# 3          Adult          M   110 m Huerden  875
# 4          Adult          M          1500 m  875
# ..           ...        ...             ...  ...
# 104          U20          W      Hochsprung  875
# 105          U20          W      Kugelstoss  840
# 106          U20          W       Speerwurf  875
# 107          U20          W  Stabhochsprung  875
# 108          U20          W      Weitsprung  840
#
# [109 rows x 4 columns]
# Diese Gruppen wurden gar nicht erst berechnet:
#    altersklasse geschlecht         disziplin    0
# 26        Adult          W  3000 m Hindernis  525
# 61          U18          W  2000 m Hindernis  175
# 79          U20          M  3000 m Hindernis   35

# %% [markdown]
# ### Some numbers of the plot for analyis

# %% [markdown]
# Initial Increases/Decreases Median and Performance Gap

# %%
# 1. Grundgesamtheit und Ausschluss (Data Gaps & Regeländerungen)
total_initial_groups = data_all.groupby(['altersklasse', 'geschlecht', 'disziplin']).ngroups

# WICHTIG: Nicht len(df.notna()) nutzen, sondern die Zeilen zählen, wo die Bedingung True ist
# Wir filtern hier die 5 Regeländerungen + die 3 Hindernis-Gaps aus
median_valid_df = analysis_results[
    (analysis_results['Median_Diff_%'].notna()) & 
    (analysis_results['Marker'] != 'Regeländerung')
]

analyzed_groups_count_median = len(median_valid_df)
analyzed_groups_count_gap = len(analysis_results) # Meist 106 (da Gap trotz Regeländerung geht)

excluded_groups_count = total_initial_groups - analyzed_groups_count_median

# 2. Median Trends (Nur signifikante Veränderungen in validen Gruppen)
improving_median = (
    (median_valid_df['Median_Diff_%'] > 0) & 
    (median_valid_df['MWU_sig'] == 'Yes')
).sum()

declining_median = (
    (median_valid_df['Median_Diff_%'] < 0) & 
    (median_valid_df['MWU_sig'] == 'Yes')
).sum()

# 3. Performance Spread (Alle 106 berechneten Gruppen)
sig_expansion = (
    (analysis_results['Gap_Diff_%'] > 0) & 
    (analysis_results['Gap_Sig_Bootstrap'] == 'Yes')
).sum()

sig_reduction = (
    (analysis_results['Gap_Diff_%'] < 0) & 
    (analysis_results['Gap_Sig_Bootstrap'] == 'Yes')
).sum()

# 4. Prozentsätze basierend auf der Gap-Grundlage (106)
perc_expansion = (sig_expansion / analyzed_groups_count_gap) * 100
perc_reduction = (sig_reduction / analyzed_groups_count_gap) * 100

# Output für deinen Text
print(f"Total Groups in Data: {total_initial_groups}")
print(f"Excluded for Median: {excluded_groups_count} (Gaps + Rule changes)")
print(f"Analyzed Median Basis: {analyzed_groups_count_median}")
print(f"Analyzed Gap Basis: {analyzed_groups_count_gap}")
print(f"--- Median Trends (Significant & Valid) ---")
print(f"Improving: {improving_median}")
print(f"Declining: {declining_median}")
print(f"--- Gap Trends (Significant) ---")
print(f"Expansion: {sig_expansion} ({perc_expansion:.2f}%)")
print(f"Reduction: {sig_reduction} ({perc_reduction:.2f}%)")
# Out:
# Total Groups in Data: 109
# Excluded for Median: 8 (Gaps + Rule changes)
# Analyzed Median Basis: 101
# Analyzed Gap Basis: 106
# --- Median Trends (Significant & Valid) ---
# Improving: 38
# Declining: 37
# --- Gap Trends (Significant) ---
# Expansion: 52 (49.06%)
# Reduction: 7 (6.60%)

# %% [markdown]
# Analysis over age groups and gender

# %%
df_clean = analysis_results[analysis_results['Marker'] != 'Regeländerung'].copy()

df_clean['Med_Imp'] = (df_clean['Median_Diff_%'] > 0) & (df_clean['P_Val_MWU'] < 0.05)
df_clean['Gap_Wide'] = (df_clean['Gap_Diff_%'] > 0) & (df_clean['Gap_Sig_Bootstrap'] == 'Yes')


table_age_gender = df_clean.groupby(['geschlecht', 'altersklasse']).agg(
    n=('group', 'count'),
    med_imp_n=('Med_Imp', 'sum'),
    gap_wide_n=('Gap_Wide', 'sum')
)
table_age_gender['med_imp_%'] = (table_age_gender['med_imp_n'] / table_age_gender['n']) * 100
table_age_gender['gap_wide_%'] = (table_age_gender['gap_wide_n'] / table_age_gender['n']) * 100

table_gender_only = df_clean.groupby('geschlecht').agg(
    n=('group', 'count'),
    med_imp_n=('Med_Imp', 'sum'),
    gap_wide_n=('Gap_Wide', 'sum')
)
table_gender_only['med_imp_%'] = (table_gender_only['med_imp_n'] / table_gender_only['n']) * 100
table_gender_only['gap_wide_%'] = (table_gender_only['gap_wide_n'] / table_gender_only['n']) * 100

print("### Vergleich nach Geschlecht & Altersklasse ###")
print(table_age_gender.round(2))
print("\n### Globaler Vergleich: Männer vs. Frauen ###")
print(table_gender_only.round(2))
# Out:
# ### Vergleich nach Geschlecht & Altersklasse ###
#                           n  med_imp_n  gap_wide_n  med_imp_%  gap_wide_%
# geschlecht altersklasse
# M          Adult         20          9          11      45.00       55.00
#            U18           15          2           8      13.33       53.33
#            U20           17          2          11      11.76       64.71
# W          Adult         19         16           4      84.21       21.05
#            U18           13          3           7      23.08       53.85
#            U20           17          6           8      35.29       47.06
#
# ### Globaler Vergleich: Männer vs. Frauen ###
#              n  med_imp_n  gap_wide_n  med_imp_%  gap_wide_%
# geschlecht
# M           52         13          30      25.00       57.69
# W           49         25          19      51.02       38.78

# %% [markdown]
# Per Discipline Group

# %%
# 1. Vorbereitung
df_ratio = analysis_results[analysis_results['Marker'] != 'Regeländerung'].copy()

# 2. Hilfsspalten für signifikante Trends anlegen (True/False)
df_ratio['is_sig_better'] = (df_ratio['Median_Diff_%'] > 0) & (df_ratio['MWU_sig'] == 'Yes')
df_ratio['is_sig_worse'] = (df_ratio['Median_Diff_%'] < 0) & (df_ratio['MWU_sig'] == 'Yes')

# 3. Gruppieren und die Treffer zählen (summiert True als 1)
ratio_stats = df_ratio.groupby('group').agg(
    sig_better=('is_sig_better', 'sum'),
    sig_worse=('is_sig_worse', 'sum')
)

# 4. Ratios berechnen (mit Schutz gegen Division durch Null)
def get_ratio_string(a, b):
    if b == 0: return "N/A"
    return f"{round(a / b, 1)} : 1"

ratio_stats['Ratio_Imp_to_Dec'] = ratio_stats.apply(lambda x: get_ratio_string(x['sig_better'], x['sig_worse']), axis=1)
ratio_stats['Ratio_Dec_to_Imp'] = ratio_stats.apply(lambda x: get_ratio_string(x['sig_worse'], x['sig_better']), axis=1)

print("### Performance Ratios by Group ###")
print(ratio_stats)
# Out:
# ### Performance Ratios by Group ###
#         sig_better  sig_worse Ratio_Imp_to_Dec Ratio_Dec_to_Imp
# group
# Jump             5         13          0.4 : 1          2.6 : 1
# Run             15          5          3.0 : 1          0.3 : 1
# Sprint          16          7          2.3 : 1          0.4 : 1
# Throw            2         12          0.2 : 1          6.0 : 1

# %% [markdown]
# # Analysis per Rank

# %% [markdown]
# Exclude the data, where 2012/13 change in weights

# %%
data_ranks_clean = data_all.copy()

u18_wurf_exclude = [
    ('U18', 'W', 'Kugelstoss'), ('U18', 'W', 'Hammerwurf'), ('U18', 'W', 'Speerwurf'),
    ('U18', 'M', 'Kugelstoss'), ('U18', 'M', 'Hammerwurf')
]

mask_u18_wurf = data_ranks_clean[['altersklasse', 'geschlecht', 'disziplin']].apply(tuple, axis=1).isin(u18_wurf_exclude)
data_ranks_clean = data_ranks_clean[~mask_u18_wurf]

data_ranks_clean['rank'] = data_ranks_clean.groupby(["jahr", "disziplin", "geschlecht", "altersklasse"])["iaaf_score"].rank(ascending=False, method='first')

# %% [markdown]
# Calculate Rank Means

# %%
def calculate_rank_diff(df, group_cols=None, num_entries=35):
    """
    Calculates the median IAAF score for the baseline and end periods 
    across the whole group per rank, then computes the % difference.
    """
    # 1. Define time periods
    df_start = df[df["jahr"].between(2001, 2005)].copy()
    df_end = df[df["jahr"].between(2021, 2025)].copy()
    
    # 2. Define how to group (always include rank)
    agg_cols = (group_cols if group_cols else []) + ["rank"]
    
    # 3. Calculate collective Medians for both periods
    # This treats the group (e.g., "Run" or "Global") as one single distribution
    mean_start = df_start.groupby(agg_cols)["iaaf_score"].mean().reset_index()
    mean_end = df_end.groupby(agg_cols)["iaaf_score"].mean().reset_index()
    
    # 4. Merge the two periods
    final = pd.merge(
        mean_start, mean_end, 
        on=agg_cols, 
        suffixes=('_start', '_end')
    )
    
    # 5. Calculate the single % Difference
    final["mean_diff_perc"] = (
        (final["iaaf_score_end"] - final["iaaf_score_start"]) / 
        final["iaaf_score_start"] * 100
    )
    
    return final

# rank
results_ranks_age      = calculate_rank_diff(data_ranks_clean, ["geschlecht", "altersklasse"], 35)
results_ranks_all      = calculate_rank_diff(data_ranks_clean, [], 35) # Leere Liste für "All"

# %% [markdown]
# Plot Ranks against change from 2001-05 to 2021-25

# %%
# 1. Setup the Plot

# 2. Define Age-specific colors (Consistent across genders)
# Blues/Dark tones for a professional look
colors = {'Adult': "#344953", "U20": "#4dbef7", "U18": "#e67e22"}


plt.set_column(column="half")
# We use Solid for Women and Dashed for Men (or vice versa)
for (age, gender), group_df in results_ranks_age.groupby(["altersklasse", "geschlecht"]):
    color = colors.get(age, "grey")
    # Using different styles to distinguish gender within the same color family
    linestyle = "dashed" if gender == "W" else "dotted" 
    label = f"{age} ({gender})"
    
    plt.plot(
        group_df["rank"], 
        group_df["mean_diff_perc"], 
        color=color, 
        linestyle=linestyle, 
        alpha=1.0,
        # label=label,
        zorder=4
    )

# 5. Global Trend (Thick Black Line)
plt.plot(
    results_ranks_all["rank"], 
    results_ranks_all["mean_diff_perc"], 
    color="red", 
    linestyle="solid", 
    label="Global Trend", 
    zorder=3
)

plt.plot([], [], color=plt.rgb.tue_gray, linestyle='dashed', label='Women')
plt.plot([], [], color=plt.rgb.tue_gray, linestyle='dotted', label='Men')
for age in unique_ages:
    plt.plot([], [], color=colors[age], linestyle='solid', label=age)

# plt.axvline(5, ymax=0.65, color=colors['U18'], linestyle=':', alpha=0.8)
# plt.axvline(8, ymax=0.65, color=colors['U18'], linestyle='--', alpha=0.8)

# plt.axvline(8,  ymax=0.65, color=colors['U20'], linestyle=':', alpha=0.8)
# plt.axvline(15, ymax=0.65, color=colors['U20'], linestyle='--', alpha=0.8)

# plt.axvline(30, ymax=0.65, color=colors['Adult'], linestyle=':', alpha=0.8)

# plt.axvline(21, ymax=0.63, color='red', linestyle='-', alpha=0.8, zorder=0)
# plt.axvline(30, ymax=0.65, color=colors['U20'], linestyle='--', alpha=0.8)

# 6. Formatting
plt.ylim(-6.5, 4)
plt.xlim(1, 35)

plt.axhline(0, color=plt.rgb.tue_dark, linestyle='-', alpha=0.5)
plt.ylabel("Performance Change (\\%)")
plt.xlabel("Rank (1 to 35)")
plt.grid(True, axis='x', linestyle=':', alpha=0.3)

# 7. Legend - Organized in 2 columns for clarity
plt.legend(title="Demographic Group", loc='lower left', ncol=2)
# plt.savefig("rank_performance_change", category="Gap Analysis")

plt.show()

# %%
# Farben definieren (Ihre Palette)
colors = {'Adult': "#344953", "U20": "#4dbef7", "U18": "#e67e22"}

# WICHTIG: Wechsel auf "full", da wir zwei Plots nebeneinander brauchen
# Wenn Sie zwingend "half" brauchen, müssen Sie die Plots untereinander (nrows=2) machen.

plt.set_column(column="full")
    
# Subplots erstellen: 1 Zeile, 2 Spalten, Y-Achse teilen für Vergleichbarkeit
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(8, 3))

# Definition der beiden Panels
panels = [("M", axes[0], "Men"), ("W", axes[1], "Women")]

for gender_code, ax, title in panels:
    # Daten filtern
    gender_data = results_ranks_age[results_ranks_age["geschlecht"] == gender_code]
    
    # Nulllinie (Die "Wasserlinie")
    ax.axhline(0, color='black', linewidth=1.5, zorder=2)
    
    for age in ['Adult', 'U20', 'U18']: # Feste Reihenfolge
        group_df = gender_data[gender_data["altersklasse"] == age]
        
        if group_df.empty:
            continue
            
        color = colors.get(age, "grey")
        
        # 1. Die Linie plotten
        ax.plot(
            group_df["rank"], 
            group_df["mean_diff_perc"], 
            color=color, 
            linestyle="solid", # Solid ist hier besser lesbar durch die Trennung
            linewidth=2,
            label=age,
            zorder=4
        )
        
        # 2. Die Fläche einfärben (Das "Meer aus Rot" vs "Grün")
        # Wir färben die Fläche zwischen y=0 und der Linie
        # where=... sorgt dafür, dass Positiv grün und Negativ rot wird
        ax.fill_between(
            group_df["rank"], 
            0, 
            group_df["mean_diff_perc"],
            where=(group_df["mean_diff_perc"] >= 0),
            facecolor='green', 
            alpha=0.05, # Sehr transparent, damit sich Schichten addieren
            interpolate=True,
            zorder=1
        )
        
        ax.fill_between(
            group_df["rank"], 
            0, 
            group_df["mean_diff_perc"],
            where=(group_df["mean_diff_perc"] < 0),
            facecolor='red', 
            alpha=0.05, 
            interpolate=True,
            zorder=1
        )

    # --- FORMATIERUNG PRO SUBPLOT ---
    ax.set_title(title, fontsize=10, fontweight='bold')
    ax.set_xlim(1, 35)
    ax.set_xticks([1, 5, 10, 15, 20, 25, 30, 35])
    ax.set_ylim(-8, 5) # Leicht angepasst für Platz
    ax.grid(True, axis='x', linestyle=':', alpha=0.3)
    ax.set_xlabel("Rank Position")
    
    # Kontext-Beschriftung (Podium vs Depth)
    # Wir platzieren Text ganz unten
    ax.text(1, -9.5, "Podium\nPotential", ha='left', va='top', fontsize=7, color='grey', clip_on=False)
    ax.text(35, -9.5, "Squad Depth\n(Basis)", ha='right', va='top', fontsize=7, color='grey', clip_on=False)

# --- SPEZIAL-ANNOTATIONEN FÜR MÄNNER (LINKS) ---
ax_m = axes[0]

# Tipping Point U18 (Rank 6)
ax_m.axvline(6, ymax=0.6, color=colors['U18'], linestyle=':', alpha=0.8)
ax_m.text(6.5, 2, "U18 Dip\n(Rank 6)", color=colors['U18'], fontsize=6, ha='left')

# Tipping Point U20 (Rank 9)
ax_m.axvline(9, ymax=0.5, color=colors['U20'], linestyle=':', alpha=0.8)
ax_m.text(9.5, -4, "U20 Dip\n(Rank 9)", color=colors['U20'], fontsize=6, ha='left', va='top')

# Global Y-Label nur links
axes[0].set_ylabel("Performance Change (%)")

# Gemeinsame Legende (nur einmal nötig, da Farben konsistent)
# Wir holen uns die Handles vom letzten Plot
handles, labels = axes[1].get_legend_handles_labels()
# Nur die ersten 3 Handles (Adult, U20, U18) nehmen, um Duplikate zu vermeiden
fig.legend(handles, labels, loc='lower center', bbox_to_anchor=(0.5, -0.15), 
            ncol=3, frameon=False, title="Age Group")

# plt.tight_layout() # Wichtig, damit Titel nicht abgeschnitten werden
# plt.savefig("rank_performance_split.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# All data percentage changes

# %%
import pandas as pd

table_df = results_ranks_age.pivot(
    index='rank', 
    columns=['altersklasse', 'geschlecht'], 
    values='mean_diff_perc'
)

table_df.columns = [f"{age} ({gen})" for age, gen in table_df.columns]

table_df['Global Trend'] = results_ranks_all.set_index('rank')['mean_diff_perc']

table_df = table_df.sort_index()

print(f"{'Rank':>4} | " + " | ".join([f"{col:>12}" for col in table_df.columns]))
print("-" * (7 + len(table_df.columns) * 15))

for rank, row in table_df.iterrows():
    values_str = " | ".join([f"{val:11.2f}%" if pd.notnull(val) else f"{'N/A':>12}" for val in row])
    print(f"{int(rank):4d} | {values_str}")

print("-" * (7 + len(table_df.columns) * 15))
# Out:
# Rank |    Adult (M) |      U18 (M) |      U20 (M) |    Adult (W) |      U18 (W) |      U20 (W) | Global Trend
# ----------------------------------------------------------------------------------------------------------------
#    1 |        2.03% |        1.23% |        1.43% |        1.29% |        1.71% |        1.78% |        1.55%
#    2 |        2.09% |        0.47% |        1.37% |        1.95% |        1.64% |        1.80% |        1.59%
#    3 |        1.51% |        0.51% |        1.55% |        2.94% |        0.85% |        2.01% |        1.64%
#    4 |        1.16% |        0.23% |        1.08% |        2.93% |        0.70% |        1.72% |        1.38%
#    5 |        1.13% |        0.13% |        1.34% |        3.10% |        0.79% |        1.59% |        1.43%
#    6 |        1.04% |       -0.27% |        0.76% |        3.18% |        0.52% |        1.27% |        1.20%
#    7 |        1.04% |       -0.48% |        0.30% |        3.16% |        0.21% |        1.21% |        1.05%
#    8 |        0.98% |       -0.56% |        0.14% |        3.42% |       -0.02% |        0.85% |        0.96%
#    9 |        0.94% |       -0.70% |       -0.25% |        3.46% |        0.06% |        0.67% |        0.86%
#   10 |        0.98% |       -0.97% |       -0.40% |        3.59% |       -0.06% |        0.42% |        0.78%
#   11 |        0.96% |       -1.03% |       -0.73% |        3.70% |       -0.06% |        0.39% |        0.73%
#   12 |        0.94% |       -1.10% |       -1.01% |        3.65% |        0.01% |        0.32% |        0.66%
#   13 |        1.13% |       -1.06% |       -1.13% |        3.67% |       -0.07% |        0.16% |        0.66%
#   14 |        1.17% |       -1.14% |       -1.32% |        3.60% |       -0.16% |        0.03% |        0.58%
#   15 |        1.07% |       -1.30% |       -1.68% |        3.38% |       -0.24% |        0.06% |        0.43%
#   16 |        1.06% |       -1.31% |       -2.02% |        3.28% |       -0.31% |       -0.17% |        0.30%
#   17 |        1.08% |       -1.29% |       -2.21% |        3.25% |       -0.31% |       -0.14% |        0.28%
#   18 |        0.98% |       -1.42% |       -2.50% |        3.20% |       -0.31% |       -0.19% |        0.18%
#   19 |        0.88% |       -1.54% |       -2.64% |        3.23% |       -0.34% |       -0.17% |        0.12%
#   20 |        0.79% |       -1.51% |       -2.71% |        3.33% |       -0.36% |       -0.36% |        0.08%
#   21 |        0.78% |       -1.70% |       -2.99% |        3.33% |       -0.47% |       -0.40% |       -0.01%
#   22 |        0.68% |       -1.91% |       -3.05% |        3.28% |       -0.53% |       -0.39% |       -0.08%
#   23 |        0.53% |       -1.93% |       -3.18% |        3.34% |       -0.53% |       -0.46% |       -0.13%
#   24 |        0.39% |       -2.08% |       -3.35% |        3.31% |       -0.65% |       -0.53% |       -0.24%
#   25 |        0.38% |       -2.15% |       -3.60% |        3.18% |       -0.60% |       -0.66% |       -0.33%
#   26 |        0.28% |       -2.25% |       -3.80% |        3.08% |       -0.64% |       -0.72% |       -0.44%
#   27 |        0.36% |       -2.37% |       -4.10% |        3.01% |       -0.63% |       -0.86% |       -0.52%
#   28 |        0.24% |       -2.53% |       -4.27% |        3.01% |       -0.66% |       -0.94% |       -0.61%
#   29 |        0.19% |       -2.61% |       -4.42% |        2.84% |       -0.77% |       -1.11% |       -0.73%
#   30 |        0.04% |       -2.84% |       -4.66% |        2.82% |       -0.83% |       -1.31% |       -0.87%
#   31 |       -0.09% |       -2.86% |       -4.87% |        2.74% |       -0.99% |       -1.32% |       -0.97%
#   32 |       -0.25% |       -3.07% |       -5.08% |        2.64% |       -1.11% |       -1.47% |       -1.13%
#   33 |       -0.49% |       -3.25% |       -5.38% |        2.51% |       -1.24% |       -1.59% |       -1.31%
#   34 |       -0.61% |       -3.38% |       -5.70% |        2.37% |       -1.29% |       -1.65% |       -1.45%
#   35 |       -0.58% |       -3.53% |       -5.95% |        2.24% |       -1.31% |       -1.71% |       -1.54%
# ----------------------------------------------------------------------------------------------------------------
