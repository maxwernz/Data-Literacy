# %%
# %run -i '../../DL Vorlesung/Preamble.py'
import numpy as np
import pandas as pd
import json
from score_calculator import score_from_mark
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 import pandas as pd
#       4 import json
# ----> 5 from score_calculator import score_from_mark
#
# File ~/Development/Data Literacy/max/iaaf_points/score_calculator.py:5
#       2 import math
#       4 # # --- Load JSON ---
# ----> 5 with open("max/iaaf_points/IAAF_2025.json") as f:
#       6     points_data = json.load(f)
#       8 with open("max/iaaf_points/IAAF_Coefficients_2025.json") as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'max/iaaf_points/IAAF_2025.json'

# %%
iaaf_points = pd.read_json('IAAF_2025.json')
iaaf_points
# Out:
#        gender      event    mark  points
# 0         men         TJ   19.19    1400
# 1         men         TJ   19.18    1399
# 2         men         TJ   19.17    1398
# 3         men         TJ   19.16    1397
# 4         men         TJ   19.15    1396
# ...       ...        ...     ...     ...
# 209363  women  Road Mile  559.28       5
# 209364  women  Road Mile  561.47       4
# 209365  women  Road Mile  563.95       3
# 209366  women  Road Mile  566.89       2
# 209367  women  Road Mile  570.73       1
#
# [209368 rows x 4 columns]

# %%
iaaf_points['event'].unique()
# Out:
# array(['TJ', 'Road 20kmW', 'Road HM', 'Hept. sh', '5000m', '300m', '200m',
#        '55mH', '60mH', '4x400m', '50mH', '400m', 'Mile sh', '600m',
#        '10000m', '20,000mW', '3000m sh', '800m sh', 'Road 3kmW', '5000mW',
#        '4x200m sh', '50m', '500m', '15,000mW', 'Road 10 Miles', '100m',
#        '4x100m', 'Road 15 km', '500m sh', '110mH', '10,000mW', '35,000mW',
#        'Road 100 km', '400mH', 'HJ', '300m sh', '4x400mix', 'Road 30kmW',
#        '2 Miles', '2000m SC', 'PV', '400m sh', 'HT', '3000m SC',
#        '30,000mW', '1500m', '4x400mix sh', 'JT', 'Road 50kmW',
#        'Road 30 km', '55m', '4x200m', '1500m sh', '3000m', 'LJ',
#        'Road 5kmW', 'Road 5 km', '3000mW', 'Road 15kmW', '50,000mW',
#        '60m', '1000m sh', 'Road 35kmW', '800m', '1000m', 'Road 10kmW',
#        'DT', '4x400m sh', 'Dec.', 'Road 20 km', '200m sh',
#        'Road Marathon', '2000m', '5000m sh', 'Mile', '2000m sh', 'SP',
# ...

# %%
iaaf_coefficients = pd.read_json('IAAF_Coefficients_2025.json')
a, b, c, = iaaf_coefficients.loc['100m', 'men']

# %%
from score_calculator import score_from_mark
fig, ax = plt.subplots()
difference = []

iaaf_100m_points = iaaf_points[(iaaf_points['event'] == '100m') & (iaaf_points['gender'] == 'men')]

colors = [rgb.tue_red, rgb.tue_blue, rgb.tue_green]
func = [None, 'ceil', 'floor']

idx = 0
for _, row in iaaf_100m_points.iterrows():
    mark = row['mark']
    official_score = row['points']
    calculated_score = score_from_mark("men", "100m", mark, iaaf_coefficients, func=func[idx])
    if calculated_score != official_score:
        print(f"Discrepancy for mark {mark}: calculated {calculated_score}, official {official_score}")
    difference.append(calculated_score - official_score)

    ax.plot(difference, '.', color=colors[idx])
    idx += 1

fig.suptitle("Difference between calculated and official IAAF points")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 14
#      12 mark = row['mark']
#      13 official_score = row['points']
# ---> 14 calculated_score = score_from_mark("men", "100m", mark, iaaf_coefficients, func=func[idx])
#      15 if calculated_score != official_score:
#      16     print(f"Discrepancy for mark {mark}: calculated {calculated_score}, official {official_score}")
#
# TypeError: score_from_mark() got an unexpected keyword argument 'func'
