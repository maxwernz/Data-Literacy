# %% [markdown]
# ## **🥈 2. Breakout- & Peak-Alter je Disziplin**
#
# **„Wann passieren die großen Leistungssprünge – und wann nicht mehr?“**
#
# ### **Warum #2?**
#
# - Nutzt geburtsjahr, jahr, altersklasse
# - Verbindet Statistik mit Sportrealität
# - Ergebnisse sind oft **kontraintuitiv**
#
# ### **Kernfrage**
#
# > Ist das Peak-Alter wirklich disziplinspezifisch – oder eher individuell?
# >
#
# ### **Überraschung**
#
# - Früher Durchbruch ≠ frühes Leistungsmaximum
# - Manche Disziplinen haben **lange Plateaus**
#
# 📊 Ideal für Heatmaps / Violinplots
#
# 🧠 Sehr gutes Beispiel für **Zeitreihen-Interpretation**

# %%
# %run -i '../../DL Vorlesung/Preamble.py'
import numpy as np
import pandas as pd
import json
from pathlib import Path
import sys
parent_path = Path().resolve().parent.parent  # notebook's parent directory
sys.path.append(str(parent_path))
import util

# %%
data = util.load_data('../../data_csv/Data_iaaf_scores_neu.csv')
data
# Out:
#         jahr geschlecht altersklasse  disziplin  leistung  wind  \
# 0       2017          W       Frauen      100 m     10.95  +1,3
# 1       2017          W       Frauen      100 m     11.06  +1,8
# 2       2017          W       Frauen      100 m     11.14  -0,2
# 3       2017          W       Frauen      100 m     11.24  +0,3
# 4       2017          W       Frauen      100 m     11.25  +1,9
# ...      ...        ...          ...        ...       ...   ...
# 226678  2023          M           14  Speerwurf     40.64   NaN
# 226679  2023          M           14  Speerwurf     40.48   NaN
# 226680  2023          M           14  Speerwurf     40.38   NaN
# 226681  2023          M           14  Speerwurf     40.36   NaN
# 226682  2023          M           14  Speerwurf     40.30   NaN
#
#                       name  geburtsjahr               verein       datum  \
# 0       Gina Lueckenkemper         1996  LG Olympia Dortmund      05.08.
# 1            Rebekka Haase         1993     LV 90 Erzgebirge      25.05.
# 2               Lisa Mayer         1996   Sprintteam Wetzlar      27.08.
# 3            Tatjana Pinto         1992         LC Paderborn      15.07.
# 4               Sina Mayer         1995     LAZ Zweibruecken      11.06.
# ...                    ...          ...                  ...         ...
# 226678       Tizian Zoeger         2010     LAC Aschersleben  29.04.2023
# 226679       Phil Matthias         2009             SV Halle  07.05.2023
# 226680        Laurin Steep         2009       MTV Dannenberg  16.09.2023
# 226681          Rico Lange         2009  TSV Chemie Premnitz  02.09.2023
# 226682     Johann Fichtner         2009   SV Preussen Berlin  02.07.2023
#
#                              ort  iaaf_score
# 0                     London/GBR        1211
# 1                     Zeulenroda        1187
# 2                         Berlin        1169
# 3                     Ninove/BEL        1148
# 4                     Regensburg        1146
# ...                          ...         ...
# 226678               Schoenebeck         545
# 226679             Halle (Saale)         543
# 226680  Fallersleben (Wolfsburg)         542
# 226681       Berlin-Lichterfelde         541
# 226682  Berlin-Hohenschoenhausen         541
#
# [226683 rows x 12 columns]

# %% [markdown]
# ## Create athlete id
# - id consists of name + birthyear
# - can be used to find athletes that have scores across multiple years and disciplines

# %%
data['athlete_id'] = (
    data['name'].str.lower()..str.replace(' ', '', regex=False)
    + '_' + data['geburtsjahr'].astype(str)
)

data
# Out:
#         jahr geschlecht altersklasse  disziplin  leistung  wind  \
# 0       2017          W       Frauen      100 m     10.95  +1,3
# 1       2017          W       Frauen      100 m     11.06  +1,8
# 2       2017          W       Frauen      100 m     11.14  -0,2
# 3       2017          W       Frauen      100 m     11.24  +0,3
# 4       2017          W       Frauen      100 m     11.25  +1,9
# ...      ...        ...          ...        ...       ...   ...
# 226678  2023          M           14  Speerwurf     40.64   NaN
# 226679  2023          M           14  Speerwurf     40.48   NaN
# 226680  2023          M           14  Speerwurf     40.38   NaN
# 226681  2023          M           14  Speerwurf     40.36   NaN
# 226682  2023          M           14  Speerwurf     40.30   NaN
#
#                       name  geburtsjahr               verein       datum  \
# 0       Gina Lueckenkemper         1996  LG Olympia Dortmund      05.08.
# 1            Rebekka Haase         1993     LV 90 Erzgebirge      25.05.
# 2               Lisa Mayer         1996   Sprintteam Wetzlar      27.08.
# 3            Tatjana Pinto         1992         LC Paderborn      15.07.
# 4               Sina Mayer         1995     LAZ Zweibruecken      11.06.
# ...                    ...          ...                  ...         ...
# 226678       Tizian Zoeger         2010     LAC Aschersleben  29.04.2023
# 226679       Phil Matthias         2009             SV Halle  07.05.2023
# 226680        Laurin Steep         2009       MTV Dannenberg  16.09.2023
# 226681          Rico Lange         2009  TSV Chemie Premnitz  02.09.2023
# 226682     Johann Fichtner         2009   SV Preussen Berlin  02.07.2023
#
#                              ort  iaaf_score               athlete_id
# 0                     London/GBR        1211  gina lueckenkemper_1996
# 1                     Zeulenroda        1187       rebekka haase_1993
# 2                         Berlin        1169          lisa mayer_1996
# 3                     Ninove/BEL        1148       tatjana pinto_1992
# 4                     Regensburg        1146          sina mayer_1995
# ...                          ...         ...                      ...
# 226678               Schoenebeck         545       tizian zoeger_2010
# 226679             Halle (Saale)         543       phil matthias_2009
# 226680  Fallersleben (Wolfsburg)         542        laurin steep_2009
# 226681       Berlin-Lichterfelde         541          rico lange_2009
# 226682  Berlin-Hohenschoenhausen         541     johann fichtner_2009
#
# [226683 rows x 13 columns]

# %% [markdown]
# ## Only keep best performance
# - filter for the best performance per year

# %%
df_best = (
    data
    .sort_values('iaaf_score', ascending=False)
    .groupby(['athlete_id', 'disziplin', 'jahr'], as_index=False)
    .first()
)

df_best
# Out:
#                            athlete_id         disziplin  jahr geschlecht  \
# 0             , luise rettschlag_1996       Siebenkampf  2010          W
# 1       aader abdelkabir zaroual_1990  3000 m Hindernis  2018          M
# 2                 aaliah koerner_2005              5 km  2021          W
# 3        aaliyah-laetitia mbenda_2004     100 m Huerden  2020          W
# 4        aaliyah-laetitia mbenda_2004     100 m Huerden  2024          W
# ...                               ...               ...   ...        ...
# 160555              zuzka walter_2007      3000 m Gehen  2022          W
# 160556              zuzka walter_2007      3000 m Gehen  2023          W
# 160557              zuzka walter_2007      3000 m Gehen  2024          W
# 160558              zuzka walter_2007              5 km  2022          W
# 160559              zuzka walter_2007              5 km  2023          W
#
#        altersklasse  leistung  wind                      name  geburtsjahr  \
# 0                14   2497.00  None        , Luise Rettschlag         1996
# 1           Maenner    555.29  None  Aader Abdelkabir Zaroual         1990
# 2            Frauen   1091.00  None            Aaliah Koerner         2005
# 3                18     14.18  -0,2   Aaliyah-Laetitia Mbenda         2004
# 4               U23     13.69   0,0   Aaliyah-Laetitia Mbenda         2004
# ...             ...       ...   ...                       ...          ...
# 160555           16   1043.97  None              Zuzka Walter         2007
# 160556           20    944.47  None              Zuzka Walter         2007
# 160557           20    947.28  None              Zuzka Walter         2007
# 160558           18   1798.00  None              Zuzka Walter         2007
# 160559           18   1758.00  None              Zuzka Walter         2007
#
#                          verein       datum          ort  iaaf_score
# 0                  SG Vehlefanz      03.07.    Jueterbog         408
# 1                  LG Eintracht       02.06   Regensburg         932
# 2                 LG Rhein-Wied  20.06.2021   Gengenbach         822
# 3            TV Wattenscheid 01  05.09.2020    Heilbronn         996
# 4       TSV Bayer o4 Leverkusen  04.05.2024      Neuwied        1058
# ...                         ...         ...          ...         ...
# 160555               ASV Erfurt  18.09.2022      Potsdam         588
# 160556               ASV Erfurt  27.06.2023       Erfurt         744
# 160557               ASV Erfurt  27.07.2024      Koblenz         739
# 160558               ASV Erfurt  09.04.2022  Reichenbach          73
# 160559               ASV Erfurt  15.04.2023       Erfurt          94
#
# [160560 rows x 13 columns]
